# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 622

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# # check to see if request work
# # print(cities)
# # http://api.openweathermap.org/data/2.5/weather?q=London,uk&APPID=d9efa5a748dc69fa16e6e6557880bc48
# url = "https://api.openweathermap.org/data/2.5/weather?"
# city = "albany"
# query_url = url + "appid=" + "d9efa5a748dc69fa16e6e6557880bc48" + "&q=" + city
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# print(json.dumps(weather_json, indent=4, sort_keys=True))
# print()
# # test extracting json data
# city_lat = weather_json['coord']['lat']
# city_lng = weather_json['coord']['lon']
# city_max_temp = weather_json['main']['temp_max']
# city_humidity = weather_json['main']['humidity']
# city_clouds = weather_json['clouds']
# city_wind = weather_json['wind']
# city_country = weather_json['sys']['country']
# city_date = weather_json['dt']
# print(f'city_lat: {city_lat}, city_lng: {city_lng}, city_max_temp: {city_max_temp}, city_humidity: {city_humidity}, city_clouds: {city_clouds}, city_wind: {city_wind}, city_country: {city_country}, city_date: {city_date}')

# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
    
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# print(len(city_data))
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chute-aux-outardes
# Processing Record 2 of Set 1 | roma
# Processing Record 3 of Set 1 | taolanaro
# Processing Record 4 of Set 1 | galiwinku
# Processing Record 5 of Set 1 | port augusta
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | tabou
# Processing Record 8 of Set 1 | kaitangata
# Processing Record 9 of Set 1 | iralaya
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | san cristobal
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | usinsk
# Processing Record 14 of Set 1 | mrirt
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | nome
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | bilma
# Processing Record 21 of Set 1 | tezu
# Processing Record 22 of Set 1 | almaznyy
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
# city_data_df = pd.DataFrame(city_data, columns = ['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
city_data_df = pd.DataFrame(city_data)


temps = city_data_df['Max Temp']
lats = city_data_df['Lat']


# # Show Record Count
city_data_df.count()
# Out:
# City          622
# Lat           622
# Lng           622
# Max Temp      622
# Humidity      622
# Cloudiness    622
# Wind Speed    622
# Country       622
# Date          622
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  chute-aux-outardes  42.6001 -73.9662    274.39        69          97
# 1                roma  42.6001 -73.9662    274.39        69          97
# 2           taolanaro  42.6001 -73.9662    274.39        69          97
# 3           galiwinku  42.6001 -73.9662    274.39        69          97
# 4        port augusta  42.6001 -73.9662    274.39        69          97
#
#    Wind Speed Country        Date
# 0        1.79      US  1674905416
# 1        1.79      US  1674905416
# 2        1.79      US  1674905416
# 3        1.79      US  1674905416
# 4        1.79      US  1674905416

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# # Read saved data
# city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  chute-aux-outardes  42.6001 -73.9662    274.39        69          97
# 1                roma  42.6001 -73.9662    274.39        69          97
# 2           taolanaro  42.6001 -73.9662    274.39        69          97
# 3           galiwinku  42.6001 -73.9662    274.39        69          97
# 4        port augusta  42.6001 -73.9662    274.39        69          97
#
#    Wind Speed Country        Date
# 0        1.79      US  1674905416
# 1        1.79      US  1674905416
# 2        1.79      US  1674905416
# 3        1.79      US  1674905416
# 4        1.79      US  1674905416

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# x_axis_max_temp = np.array(city_data_df['Max Temp'])
# y_axis_Lat = np.array(city_data_df['Lat'])

# city_data_df = pd.DataFrame(city_data)

# city_data_df = city_data_df.reset_index()
# print(city_data_df.head())
# temps = city_data_df.loc[:,['Max Temp']]
# lats = city_data_df.loc[:,['Lat']]

# temps = city_data_df['Max Temp']
# lats = city_data_df['Lat']

# lats = city_data_df['Lat'].to_list()

plt.scatter(temps,
            lats,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# fig, ax = plt.subplots(figsize=(11, 8))

# plt.scatter(x_axis_max_temp, y_axis_Lat, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
plt.grid()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
date_now = datetime.date(datetime.now())
plt.title(f'City Latitude vs Max Temperature ({date_now})')
# # plt.scatter(x_axis_Lat, y_axis_max_temp, marker="o", facecolors="red", edgecolors="black",
# #             s=x_axis, alpha=0.75)
# # plt.scatter(y_axis, y_axis_max_temp, marker="x", facecolors="green",
# #             s=x_axis, alpha=0.75)
# # plt.scatter(x_axis_Lat, y_axis_max_temp)
# plt.xlim(-700, 700)
# plt.ylim(-700, 700)

plt.savefig("output_data/Fig1.png")
plt.show()
# print('complete')

# # x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
# # y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
# # print(type(x))
# # plt.scatter(x, y)
# # plt.show()




# # # Incorporate the other graph properties
# # # YOUR CODE HERE

# # # Save the figure
# # plt.savefig("output_data/Fig1.png")

# # # Show plot
# # plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
